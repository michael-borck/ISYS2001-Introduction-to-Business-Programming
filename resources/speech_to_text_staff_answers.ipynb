# %% [markdown]
# # Tips, Tricks, Notes
#
# This notebook is the first time we will need to install missing packages.
#
# The 'missing' link or common question is how do I know to use this package. If time allows, I demonstrate by googling the problem and then decide to use the package based on my reading of the pages, trust/faith in the webpage source, etc. I try to demonstrate the process of finding information to solve my problem (or learning how to learn).
#
# In this instance, we need to install a package BEFORE we can use the package. We will discuss PIP and WGET and PyPy etc., in the next week, but this notebook serves as a good introduction.
#
# This notebook also uses file io. We need an audio file source. We could download, upload to Colab. The 'upload' can get a little complex as we need to understand google drive, mounting the drive, paths to folders etc. For now, the easier option is to use wget, and it will download the audio file the location of the notebook.
#
# To process the audio file, we use **with** statement. The **with** statement is used in the exception handline to make the code cleaner. See [with statement in Python](https://www.geeksforgeeks.org/with-statement-in-python/) for more details.
#
# Finally here is the link to site this notebook is based on:[How to Convert Speech to Text in Python](https://www.thepythoncode.com/article/using-speech-recognition-to-convert-speech-to-text-python).
#
# It might be worth mentioning the issues of 'large' audio files and perhaps discussing our initial approach to use a small file, getting the process working, and then considering a bigger file (this is out the test with other data steps).

# %%
# !wget https://www.pacdv.com/sounds/voices/maybe-next-time.wav
# !pip install SpeechRecognition

# %%
import IPython
filename = 'maybe-next-time.wav'
IPython.display.Audio(filename)

# %%
import speech_recognition as sr
# initialize the recognizer
r = sr.Recognizer()
# open the file
text = None
with sr.AudioFile(filename) as source:
    # listen for the data (load audio to memory)
    audio_data = r.record(source)
    # recognize (convert from speech to text)
    text = r.recognize_google(audio_data)
    print(text)

# %%
with open("text-from-speech.txt",'w') as f:
  f.write(text)
