# %%
### useful example of doctest usage
def my_func(x, y, z):
    """
    >>> my_func(1, 2, 3)
    5
    >>> my_func('hello ', 3, 'world')
    'hello hello hello world'
    >>> my_func(0, 0, 0)
    what happens when things are wrong?
    """
    return x * y + z

# %%
def my_fun():
    '''
    >>> 2 + 3
    6
    '''
    pass

# %%
import doctest
doctest.testmod()
# Out:
# **********************************************************************
# File "__main__", line 3, in __main__.my_fun
# Failed example:
#     2 + 3
# Expected:
#     6
# Got:
#     5
# **********************************************************************
# File "__main__", line 8, in __main__.my_func
# Failed example:
#     my_func(0, 0, 0)
# Expected:
#     what happens when things are wrong?
# Got:
#     0
# **********************************************************************
# 2 items had failures:
#    1 of   1 in __main__.my_fun
#    1 of   3 in __main__.my_func
# ***Test Failed*** 2 failures.
# TestResults(failed=2, attempted=4)

# %%
assert sum([1, 2, 3]) == 6, "Should be 6"

# %%
assert sum([1, 1, 3]) == 6, "Should be 6"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-7-11127dbe743f> in <module>()
# ----> 1 assert sum([1, 1, 3]) == 6, "Should be 6"
#
# AssertionError: Should be 6

# %%
def test_square():
   n = 2
   assert n*n == 4
 
def test_cube():
   n = 2
   assert n*n*n == 8

# %%
def run_tests():
  test_square()
  test_cube()

# %%
def add(a, b):
    return a + b

# %%
import unittest

class TestNotebook(unittest.TestCase):
    
    def test_add(self):
        self.assertEqual(add(2, 2), 4)

# %%
unittest.main(argv=[''], verbosity=2, exit=False)
# Out:
# test_add (__main__.TestNotebook) ... ok
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.004s
#
# OK

# %%
def add2(a, b):
    '''
    This is the test:
    >>> add2(2, 2)
    5
    '''
    import pdb; pdb.set_trace()
    return a + b

# %%
import doctest
doctest.testmod()
# Out:
# > <ipython-input-25-34425da979c0>(8)add2()
# -> return a + b
# (Pdb) help s
# s(tep)
#         Execute the current line, stop at the first possible occasion
#         (either in a function that is called or in the current
#         function).
# (Pdb) s
# --Return--
# > <ipython-input-25-34425da979c0>(8)add2()->4
# -> return a + b
# (Pdb) s
# --Return--
# > <doctest __main__.add2[0]>(1)<module>()->None
# -> add2(2, 2)
# (Pdb) s
# > /usr/lib/python3.7/doctest.py(1338)__run()
# -> self.debugger.set_continue() # ==== Example Finished ====
# (Pdb) s
# --Call--
# > /usr/lib/python3.7/doctest.py(373)set_continue()
# -> def set_continue(self):
# (Pdb) s
# > /usr/lib/python3.7/doctest.py(376)set_continue()
# -> if self.__debugger_used:
# (Pdb) s
# > /usr/lib/python3.7/doctest.py(377)set_continue()
# -> pdb.Pdb.set_continue(self)
# (Pdb) s
# --Call--
# > /usr/lib/python3.7/bdb.py(334)set_continue()
# -> def set_continue(self):
# (Pdb) n
# > /usr/lib/python3.7/bdb.py(340)set_continue()
# -> self._set_stopinfo(self.botframe, None, -1)
# (Pdb) n
# **********************************************************************
# File "__main__", line 4, in __main__.add2
# Failed example:
#     add2(2, 2)
# Expected:
#     5
# Got:
#     4
# **********************************************************************
# File "__main__", line 3, in __main__.my_fun
# Failed example:
#     2 + 3
# Expected:
#     6
# Got:
#     5
# **********************************************************************
# File "__main__", line 8, in __main__.my_func
# Failed example:
#     my_func(0, 0, 0)
# Expected:
#     what happens when things are wrong?
# Got:
#     0
# **********************************************************************
# 3 items had failures:
#    1 of   1 in __main__.add2
#    1 of   1 in __main__.my_fun
#    1 of   3 in __main__.my_func
# ***Test Failed*** 3 failures.
# TestResults(failed=3, attempted=5)

# %%
pip install ipython_unittest
# Out:
# Collecting ipython_unittest
#   Downloading ipython_unittest-0.3.1-py2.py3-none-any.whl (15 kB)
# Installing collected packages: ipython-unittest
# Successfully installed ipython-unittest-0.3.1

# %%
pip install jupyter_dojo
# Out:
# Requirement already satisfied: jupyter_dojo in /usr/local/lib/python3.7/dist-packages (0.3.2)
# Requirement already satisfied: ipython-unittest>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from jupyter_dojo) (0.3.1)
# Requirement already satisfied: ipython>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from jupyter_dojo) (7.27.0)
# Requirement already satisfied: notebook>=4.3.0 in /usr/local/lib/python3.7/dist-packages (from jupyter_dojo) (5.3.1)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython>=1.0.0->jupyter_dojo) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from ipython>=1.0.0->jupyter_dojo) (3.0.20)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython>=1.0.0->jupyter_dojo) (57.4.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython>=1.0.0->jupyter_dojo) (2.10.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.7/dist-packages (from ipython>=1.0.0->jupyter_dojo) (0.2.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython>=1.0.0->jupyter_dojo) (4.4.2)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.7/dist-packages (from ipython>=1.0.0->jupyter_dojo) (4.8.0)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.7/dist-packages (from ipython>=1.0.0->jupyter_dojo) (5.0.5)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.7/dist-packages (from ipython>=1.0.0->jupyter_dojo) (0.1.2)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.7/dist-packages (from ipython>=1.0.0->jupyter_dojo) (0.18.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from jedi>=0.16->ipython>=1.0.0->jupyter_dojo) (0.8.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.3.0->jupyter_dojo) (2.11.3)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.7/dist-packages (from notebook>=4.3.0->jupyter_dojo) (5.1.3)
# Requirement already satisfied: tornado>=4 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.3.0->jupyter_dojo) (5.1.1)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.7/dist-packages (from notebook>=4.3.0->jupyter_dojo) (6.4.1)
# Requirement already satisfied: jupyter-core>=4.4.0 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.3.0->jupyter_dojo) (4.7.1)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.7/dist-packages (from notebook>=4.3.0->jupyter_dojo) (5.6.1)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.7/dist-packages (from notebook>=4.3.0->jupyter_dojo) (0.2.0)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.7/dist-packages (from notebook>=4.3.0->jupyter_dojo) (1.8.0)
# Requirement already satisfied: jupyter-client>=5.2.0 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.3.0->jupyter_dojo) (7.0.2)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.3.0->jupyter_dojo) (0.11.0)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.7/dist-packages (from jupyter-client>=5.2.0->notebook>=4.3.0->jupyter_dojo) (22.2.1)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from jupyter-client>=5.2.0->notebook>=4.3.0->jupyter_dojo) (2.8.2)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.7/dist-packages (from jupyter-client>=5.2.0->notebook>=4.3.0->jupyter_dojo) (1.5.1)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.7/dist-packages (from jupyter-client>=5.2.0->notebook>=4.3.0->jupyter_dojo) (0.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect>4.3->ipython>=1.0.0->jupyter_dojo) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=1.0.0->jupyter_dojo) (0.2.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.1->jupyter-client>=5.2.0->notebook>=4.3.0->jupyter_dojo) (1.15.0)
# Requirement already satisfied: argcomplete>=1.12.3 in /usr/local/lib/python3.7/dist-packages (from ipykernel->notebook>=4.3.0->jupyter_dojo) (1.12.3)
# Requirement already satisfied: importlib-metadata<5 in /usr/local/lib/python3.7/dist-packages (from ipykernel->notebook>=4.3.0->jupyter_dojo) (4.6.4)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel->notebook>=4.3.0->jupyter_dojo) (1.0.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata<5->ipykernel->notebook>=4.3.0->jupyter_dojo) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata<5->ipykernel->notebook>=4.3.0->jupyter_dojo) (3.5.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->notebook>=4.3.0->jupyter_dojo) (2.0.1)
# Requirement already satisfied: testpath in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.3.0->jupyter_dojo) (0.5.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.3.0->jupyter_dojo) (0.7.1)
# Requirement already satisfied: bleach in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.3.0->jupyter_dojo) (4.0.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.3.0->jupyter_dojo) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.3.0->jupyter_dojo) (1.4.3)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /usr/local/lib/python3.7/dist-packages (from nbformat->notebook>=4.3.0->jupyter_dojo) (2.6.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach->nbconvert->notebook>=4.3.0->jupyter_dojo) (0.5.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from bleach->nbconvert->notebook>=4.3.0->jupyter_dojo) (21.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->bleach->nbconvert->notebook>=4.3.0->jupyter_dojo) (2.4.7)

# %%
# %load_ext ipython_unittest

# %%
# %%unittest_testcase
# def test_1_plus_1_equals_2(self):
#     sum = 1 + 1
#     self.assertEqual(sum, 2)
#
# def test_2_plus_2_equals_4(self):
#     self.assertEqual(2 + 2, 4)
# Out:
# Success
# ..
# ----------------------------------------------------------------------
# Ran 2 tests in 0.000s
#
# OK
# <unittest.runner.TextTestResult run=2 errors=0 failures=0>
