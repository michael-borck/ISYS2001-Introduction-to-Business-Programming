# %% [raw]
# ---
# title: "Functions"
# subtitle: "Weather Adventures in Python Land"
# author: "Michael Borck"
# format:
#   pptx:
#     reference-doc: ../../../_assets/template.pptx
#   pdf:
#       toc: false
#       colorlinks: true
#   docx:
#       toc: false
#       highlight-style: github
#   html:
#       toc: true
#       toc-expand: 2
#       embed-resources: true
# ---

# %% [markdown]
# # Copyright Information
#
# ![](../../../_assets/curtin-copy-right.png)
#
# # Acknowledge of Country
# I acknowledge the traditional custodians of the land on which I work and live,
# and recognise their continuing connection to land, water and community. I pay
# respect to elders past, present and emerging.
#
# ![](../../../_assets/ack_country.png)
#
# # Today's Learning Outcomes
# - Why we need functions (code organisation, reusability)
# - Function syntax in Python
# - Defining and calling functions
# - Parameters and return values
# - Scope and variable visibility
#
#
# # Why Functions?
# - Reusability: Write once, reuse everywhere.
# - Modularity: Break tasks into smaller parts.
# - Abstraction: Simplify complex tasks easily.
# - Organisation: Keep code clean and structured.
# - Scalability: Grow programs with ease.
# - Testing: Easier to test and fix..
#
# # Function Syntax
# ```python
# def function_name(parameters):
#     # Function body
#     return value
# ```
#
# # Defining Functions

# %%
#| echo: true
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Using Functions for Code Organisation
#
# ```python
# temp = 25
# humidity = 60
#
# if temp > 30 and humidity > 70:
#     print('Hot and humid')
# elif temp < 0:
#     print('Freezing')
# else:
#     print('Moderate')
# ```
#
# # Reusable Weather Logic
#
# ```python
# def categorise_weather(temp, humidity):
#     if temp > 30 and humidity > 70:
#         return 'Hot and humid'
#     elif temp < 0:
#         return 'Freezing'
#     else:
#         return 'Moderate'
# ```
#
# # Applying Functions with Loops
#
# ```python
# for day in range(7):
#     temp = get_temperature(day)
#     humidity = get_humidity(day)
#     category = categorise_weather(temp, humidity)
#     print(f'Day {day + 1}: {category}')
# ```
#
# ## 2. Creating Weather-related Functions
#    - Example: Converting temperature (Celsius to Fahrenheit)
#    - Example: Calculating average temperature
#    - Example: Determining weather description based on conditions
#
# ## 3. Importing and Using Modules
#    - What are modules and why use them?
#    - The import statement and its variations
#    - Brief introduction to pip for installing third-party modules
#    - Exploring some built-in modules (e.g., math, random, datetime)
#
# ## 4. Working with a Weather API Module
#    - Introduction to a simple weather API module
#    - Fetching real-time weather data
#    - Combining custom functions with API calls
#
# ## 5. Hands-on Exercise
#    - Create a set of weather utility functions, incorporating both custom functions and imported module functions
