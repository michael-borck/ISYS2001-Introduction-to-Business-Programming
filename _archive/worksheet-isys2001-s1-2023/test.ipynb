# %% [markdown]
# <a href="https://colab.research.google.com/github/michael-borck/worksheet-isys2001-s1-2023/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world!")

# %%
print("Good Bye")
