# %% [markdown]
# ## Running Cells

# %% [markdown]
# Jupyter Notebooks are an interactive environment for writing and running code. The notebook is capable of running code in a wide range of languages. However, each notebook is associated with a single language kernel.  In this unit our notebooks will run the Python 3 language kernel.

# %% [markdown]
# Run a code cell using `Shift-Enter` or pressing the <button class='btn btn-default btn-xs'><i class="icon-step-forward fa fa-play"></i></button> button in the toolbar above:

# %%
a = 10

# %%
print(a)
# Out:
# 10

# %% [markdown]
# There are two other keyboard shortcuts for running code:
#
# * `Alt-Enter` runs the current cell and inserts a new one below.
# * `Ctrl-Enter` run the current cell and enters command mode.
#
# ## Stop running cells
#
# Sometimes, you might want to quit the execution of a code-cell because it’s taking too long (or worse, you created an infinite loop!). To do so, click the stop icon ■ in the top menu!

# %% [markdown]
# ## Managing the Kernel

# %% [markdown]
# Code is run in a separate process called the Kernel.  The Kernel can be interrupted or restarted.  Try running the following cell and then hit the <button class='btn btn-default btn-xs'><i class='icon-stop fa fa-stop'></i></button> button in the toolbar above.

# %%
import time
time.sleep(10)

# %% [markdown]
# ## Cell menu

# %% [markdown]
# The "Cell" menu has a number of menu items for running code in different ways. These includes:
#
# * Run and Select Below
# * Run and Insert Below
# * Run All
# * Run All Above
# * Run All Below

# %% [markdown]
# ## Restarting the kernels

# %% [markdown]
# The kernel maintains the state of a notebook's computations. You can reset this state by restarting the kernel. This is done by clicking on the <button class='btn btn-default btn-xs'><i class='fa fa-repeat icon-repeat'></i></button> in the toolbar above.

# %% [markdown]
# ## Standard Out (sys.stdout)

# %% [markdown]
# The standard output of a cell is displayed as text in the output area.  Technically this is to the stream sys.stdout.  We will discuss more about streams later in the semester.

# %%
print("hi, stdout")
# Out:
# hi, stdout

# %% [markdown]
# ## Output is asynchronous

# %% [markdown]
# All output is displayed asynchronously as it is generated in the Kernel. If you execute the next cell, you will see the output one piece at a time, not all at the end.
#
# *Note: We will learn more about importing libraries and running loops later in the semester*

# %%
import time, sys
for i in range(8):
    print(i)
    time.sleep(0.5)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7
