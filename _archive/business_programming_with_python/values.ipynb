# %% [markdown]
# # Values
#
# Computers do two things really well. ***Store values*** and ***perform operations*** on those values
#
# You might think they’re doing a whole lot more, as you send texts, shop online, or rely on your phone to navigate in your car; however, everything computers do can be broken down into simple operations that are performed on simple values.
#
# Now, part of computational thinking is learning to use these operations and values to build something that is much more sophisticated, complex, and meaningful—and we’re going to get to that.
#
# First, though, we’re going to take a look at what these values are, the operations you can perform on them, and just what role variables play in all this.
#
# ### What is a value?
#
# It helps to have a good understanding of the nature and structure of the data being processed.
#
# Data within a program may be a single value, such as a number.  In the cell below try some different numbers, say 123, or 31.7.

# %%
123
# Out:
# 123

# %%
31.7
# Out:
# 31.7

# %% [markdown]
# Data within a program may be a single value, such as a character.  Are the quotes important? Is 'A' different from 'a'?

# %%
A
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/td/0ssnsqp552zcwcntj5wy94n80000gn/T/ipykernel_19643/378453753.py in <module>
# ----> 1 A
#
# NameError: name 'A' is not defined

# %%
'A'
# Out:
# 'A'

# %% [markdown]
# Data within a program may be a single value, such as True or False.  In programming we call the a boolean value, sometimes abbreviated as bool.

# %%
True
# Out:
# True

# %% [markdown]
# Data within a program may be a group items such as a tuple.  In python we use round brackets '()' to represent a tuple.  See the notebook on tuples for more information.

# %%
(1,'A')
# Out:
# (1, 'A')

# %% [markdown]
# We can also group things in a list. In python we recognise a list by using the square brackets. The list could contain the same or different type of values.

# %%
[1,'two', 31.7]
# Out:
# [1, 'two', 31.7]

# %% [markdown]
# We call a sequence of characters a 'String'.  The sequence is enclosed in quotes, either single or double quotes.  The quotes are important, without them Python thinks the sequence of characters is the name of a variable or object in the program.  See the notebook of variable and identifiers for more information.

# %%
'Michael'
# Out:
# 'Michael'

# %% [markdown]
# # The type() function
#
# Is there a way to determine the type of an item is? In Python we have a the *type()* function. In the cell below, find out the type of  3, 3.0, '3', '3.0'  and [3, 3.0,'3', '3.0'].
#
# > Note: We are going to use functions a lot, before long you will understand exactly how they work and even know how to create your own, but for now just think of them as a way to *ask* Python to do some work.  In the cell is known as **calling** the *type* function.  Functions have a name followed by left parenthesis, a data item and end with a right parenthesis.

# %%
type(31.7)
# Out:
# float

# %% [markdown]
# # The print() funciton.
#
# We have be relying on the REPL environment to display output of the last line in a cell executed.  We can have better control using the print() function.
#
# The print() function, will try to output the value we put between the round parenthesis as text in the below the current cell.

# %%
print(31.7)
print('Michael')
# Out:
# 31.7
# Michael

# %% [markdown]
# Most functions output a value. We can use the output value of one function as input value to print function.  We will discuss function more later in the semester, but here we can begin to see some of the power form programming and using functions.

# %%
print(31.7)
print(type(31.7))
# Out:
# 31.7
# <class 'float'>
