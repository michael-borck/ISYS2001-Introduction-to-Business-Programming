# %% [markdown]
# "Hello world" in Python
# ===
# Lets write our first program. "Hello world!" this is a simple program that shows whether your computer is properly set up to run Python programs.

# %%
print('Hello world!')
# Out:
# Hello world!

# %% [markdown]
# If it works, congratulations! You just ran your first Python program.
#
# There is a lot going on here, we are using a function to print out a string.  We have a program cell and an output cell.  We will discuss these concepts more during the semester.
#
# ## Name your Notebook
#
# All program and notebooks need to have a meaningful name.  Click on the name in the top left of the Colab notebook and change *Untitled.ipynb* to something more descriptive, say *Hellow WOrld.ipynb*
