# %% [markdown]
# # Input and Output
#
# We been writing simple program across the various notebooks. We have been using
# variable to store out data within the program. And at time prompting the user
# for input.
#
# This is okay for small programs.  But what about program than need to process
# large data.  We need a way to be able to read in data form a file and save the
# processing.
#
# ## Text File
# A text file is a file that can be opened in a text editor and is human readable.
# Examples include:
# * Plain text
# * XML
# * CAS
# * JSON
# * Source Code
#
# ## Binary Files
# A binary files is a file whose contents required a computer program to interpret
# the contents.  The binary file is NOt human readable.  Examples include:
# * compiled code
# * application data
# * Media files
#   * images
#   * audio
#   * video
#
# ## Python file IO
#
# Python has several functions for creating, reading, updating, and deleting files.
#
# The key function for working with files in Python is the *open()* function.
#
# The open() function takes two parameters; filename, and mode.
#
# There are four different methods (modes) for opening a file:
# * "r" - Read - Default value. Opens a file for reading, error if the file does not exist
# * "a" - Append - Opens a file for appending, creates the file if it does not exist
# * "w" - Write - Opens a file for writing, creates the file if it does not exist
# * "x" - Create - Creates the specified file, returns an error if the file exists
#
# In addition you can specify if the file should be handled as binary or text mode
#
# * "t" - Text - Default value. Text mode
# * "b" - Binary - Binary mode (e.g. images)
#
# For example
#
#     f = open("myfile.txt", "rt")
#
# Because "r" for read, and "t" for text are the default values, you do not need to specify them
#
#     f = open("myfile.txt")
#
#
# ## Write to a file
# Three steps
# 1. Open the file in appropriate mode. To open a file in Python, use the open()
#    method, with one of the following parameters:
#       * "x" - Create - will create a file, returns an error if the file exist
#       * "a" - Append - will create a file if the specified file does not exist otherwise append to end of file
#       * "w" - Write - will create a file if the specified file does not exist, otherwise overwrite any existing content
# 2. Write data to the file.  To write to a file, once it is open use the write() method
# 3. close the file To close a file, use the close() method.
#
# The open() function will return a file handle.  we use the files handle for all processing.

# %%
# Open/create a new file if it does not exist:
f = open("myfile.txt", "w")

# Write some data
f.write("This is a line of text")

# Close the file
f.close()

# %% [markdown]
# ## Read from a file
#
# Three steps
# 1. Open the file
# 2. Read the data
# 3. Close the file

# %%
# Open file if it does not exist:
f = open("myfile.txt", "r")

# Loop through the file line by line
for line in f:
  print(line)

# Close the file
f.close()
# Out:
# This is a line of text

# %% [markdown]
# We wil go through examples of input/output during the course. These steps are
# the same for all files, streams and databases.
# 1. Open/connect to the file, stream or database
# 2. Red/Write/Process the data
# 3. Close the file, stream or database
