# %% [markdown]
# # Input Validation
#
# Input validation code verifies that user supplied data, such as text from the input() function, is formatted appropriately.
#
# * try/except
# * isdigit()
# * pyinputplus
#
# ## try/except

# %%
while True:
  try:
    age = int(input('How old are you? '))
    print('Your age is: ' + str(age))
    break
  except ValueError:
    print('Please enter a whole number for your age')

# %% [markdown]
# ## isdigit()

# %%
while True:
  try:
    age = int(input('How old are you? '))
    if age.isdigit():
      print('Your age is: ' + str(age))
      break
    else:
      print('Please enter a whole number for your age')

# %% [markdown]
# ## Module: pyinputs

# %%
# install the module
# !pip install PyInputPlus
# Out:
# Requirement already satisfied: PyInputPlus in /usr/local/Caskroom/mambaforge/base/lib/python3.9/site-packages (0.2.12)
# Requirement already satisfied: stdiomask>=0.0.3 in /usr/local/Caskroom/mambaforge/base/lib/python3.9/site-packages (from PyInputPlus) (0.0.6)
# Requirement already satisfied: pysimplevalidate>=0.2.7 in /usr/local/Caskroom/mambaforge/base/lib/python3.9/site-packages (from PyInputPlus) (0.2.12)

# %%
import pyinputplus as pyip

age = pyip.inputNum(prompt="How old are you ", greaterThan=10)
print()
print('Your age is: ' + str(age))
# Out:
# How old are you
# Your age is: 12
